# %% [markdown]
# <a href="https://colab.research.google.com/github/jojovputtkamer/NLP_WiSe25.26/blob/main/jojovputtkamer_Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/soberbichler/NLP-Course4Humanities_2025.github.io.git
# Out:
# Cloning into 'NLP-Course4Humanities_2025.github.io'...
# remote: Enumerating objects: 1671, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 1671 (delta 40), reused 23 (delta 23), pack-reused 1622 (from 2)
# Receiving objects: 100% (1671/1671), 82.61 MiB | 39.00 MiB/s, done.
# Resolving deltas: 100% (959/959), done.

# %%
import pandas as pd

# Replace 'your_file.xlsx' with the actual path to your Excel file.
df = pd.read_excel('/content/NLP-Course4Humanities_2025.github.io/datasets/Data_exercise_1.xlsx')

# Display the first few rows of the DataFrame to verify it's loaded correctly.
df = df[:400]
df.head(5)
# Out:
#                                              page_id  pagenumber  \
# 0  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-8f451700...          33
# 1  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-91c3b5fd...          18
# 2  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-966a0a0c...           1
# 3  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-9b22777c...          17
# 4  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-c7c7b5d0...           3
#
#                                          paper_title  \
# 0  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 1  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 2  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 3  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 4  Leipziger Tageblatt und Handelszeitung : Amtsb...
#
#                     provider_ddb_id  \
# 0  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 1  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 2  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 3  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 4  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
#
#                                             provider     zdb_id  \
# 0  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 1  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 2  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 3  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 4  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
#
#      publication_date place_of_distribution language  \
# 0 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 1 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 2 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 3 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 4 1909-01-01 12:00:00           ['Leipzig']  ['ger']
#
#                               thumbnail  \
# 0  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 1  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 2  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 3  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 4  fd3cfa5d-fb68-4650-adb0-26861c4ac643
#
#                                         pagefulltext  \
# 0  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 1  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 2  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 3  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 4  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
#
#                                             pagename  \
# 0  uuid-8f451700-f093-407d-bb23-daa1c9051bcd_DDB_...
# 1  uuid-91c3b5fd-4645-4d4b-96c6-6d58833b3954_DDB_...
# 2  uuid-966a0a0c-107a-4cce-9763-0b40e044f2e6_DDB_...
# 3  uuid-9b22777c-8649-4bb9-8a14-3288f34a8607_DDB_...
# 4  uuid-c7c7b5d0-595d-4b07-a160-7aafb1346ad2_DDB_...
#
#                                    preview_reference  \
# 0  https://api.deutsche-digitale-bibliothek.de/bi...
# 1  https://api.deutsche-digitale-bibliothek.de/bi...
# 2  https://api.deutsche-digitale-bibliothek.de/bi...
# 3  https://api.deutsche-digitale-bibliothek.de/bi...
# 4  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                    plainpagefulltext
# 0  8. Berlage Freitag, 1. Januar 1WV. Leipziger T...
# 1  Rr. 1. Jahrg. „Haben Die schon gelesen? In Cat...
# 2  «ezugtz-Vrritz M» M»»« I»»« M UeMM»» «» «schif...
# 3  4. Beilage Freitag, 1. Januar 1VVS. Leipziger ...
# 4  Freitag, 1. Januar 1»»». und russischen Hol»!"...

# %% [markdown]
# 1. Clean, tokenize, and lemmatize the corpus
# 2. Find the most frequent verbs (use the NLTK package for this task)
# 3. Visualize the most frequent verbs with a visualization of your choice

# %%
import re
#Function to clean

def initial_clean(text):
    text = re.sub(r'[^\w\s]','',text)   # Sonderzeichen werden rausgeschmissen
    text = text.lower()
    return text

df['cleaned'] = df['plainpagefulltext'].apply(initial_clean)
df['cleaned'][:10]
# Out:
# 0    8 berlage freitag 1 januar 1wv leipziger tageb...
# 1    rr 1 jahrg haben die schon gelesen in cattaro ...
# 2    ezugtzvrritz m m i m uemm  schift ahaaiffe 8 s...
# 3    4 beilage freitag 1 januar 1vvs leipziger tage...
# 4    freitag 1 januar 1 und russischen hol zuträgli...
# 5    nr 1 tb jahrg leipziger tageblatt freitag 1 ja...
# 6    nr 1 1üs jahrg freitag 1 januar isvs leipziger...
# 7    der russischösterreichische noten wechsel zur ...
# 8    lrrzeigepreis bezugtzprei amkrtamm handelszeit...
# 9    nr 3 1v3 jahrg leipziger tageblatt dienstag s ...
# Name: cleaned, dtype: object

# %%
# es werden Listen mit Text erstellt

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

def tokenize(text):
  text = nltk.word_tokenize(text, language = 'german')
  return text

#continue the code
df['tokenized'] = df['cleaned'].apply(tokenize)
df['tokenized'][:5]  # Anzahl der Ansichtszeilen
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 0    [8, berlage, freitag, 1, januar, 1wv, leipzige...
# 1    [rr, 1, jahrg, haben, die, schon, gelesen, in,...
# 2    [ezugtzvrritz, m, m, i, m, uemm, schift, ahaai...
# 3    [4, beilage, freitag, 1, januar, 1vvs, leipzig...
# 4    [freitag, 1, januar, 1, und, russischen, hol, ...
# Name: tokenized, dtype: object

# %%
# Worte auf ihren Stamm kürzen, damit wir letzendlich eine aussagekräftige Wortwolke bekommen

import spacy
from nltk.corpus import stopwords
nltk.download('stopwords')



# Ensure the German language model is downloaded
# !python -m spacy download de_core_news_sm

# Load the German language model
nlp = spacy.load('de_core_news_sm')

# Get German stop words and add custom ones
stop_words = set(stopwords.words('german'))
custom_stop_words = {'herr', 'frau', 'dez', 'januar', 'ge', 'nr', 'ſind', 'handeln', 'ver', 'ent', 'bi'}
stop_words.update(custom_stop_words)

def lemmatize_and_remove_stopwords(texts):
    texts_out = []
    for sent in texts:
        # Join the tokens into a single string
        text = " ".join(sent)


        # Process the text with spaCy
        doc = nlp(text)

        # Lemmatize, lowercase, and remove stop words (= Füllwörter, Wörter ohne semantische Bedeutung der, die, das, und ...)
        lemmatized = [token.lemma_.lower() for token in doc
                      if token.is_alpha and token.lemma_.lower() not in stop_words]

        texts_out.append(lemmatized)

    return texts_out

# Apply the function to the DataFrame
df['lemmatized'] = lemmatize_and_remove_stopwords(df['tokenized'])

# Display the first 5 rows of the lemmatized column
df['lemmatized'].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Collecting de-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.8.0/de_core_news_sm-3.8.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 81.2 MB/s eta 0:00:00
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# 0    [berlage, freitag, leipziger, tageblatt, rr, i...
# 1    [rr, jahrg, schon, lesen, cattaro, schießen, b...
# 2    [ezugtzvrritz, m, m, i, m, uemm, schifen, ahaa...
# 3    [beilage, freitag, leipziger, tageblatt, iva, ...
# 4    [freitag, russisch, hol, zuträglich, erachten,...
# Name: lemmatized, dtype: object

# %%
def tagging(texts, allowed_postags=['VERB']): # possible tags'NOUN', 'ADJ', 'ADV', 'VERB'
    texts_out = []
    nlp = spacy.load('de_core_news_sm')
    for sent in texts:
        sent_str = " ".join(sent)
        doc = nlp(sent_str)
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

df['tagging'] = tagging(df['lemmatized'])
df['tagging'][:5]
# Out:
# 0    [veröffentlichen, betracht, gehen, überblicken...
# 1    [schießen, stehen, glauben, dementieren, traue...
# 2    [neiten, vtlaababr, hanruual, rnpha, finden, t...
# 3    [sagen, licken, ehren, blicklich, veranlassen,...
# 4    [verstehen, gessen, boqkottbeweguug, find, beg...
# Name: tagging, dtype: object

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Flatten the list of lists of lemmatized words into a single list
all_words = [word for sublist in df['tagging'] for word in sublist]

# Create a string of all words
text = ' '.join(all_words)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
