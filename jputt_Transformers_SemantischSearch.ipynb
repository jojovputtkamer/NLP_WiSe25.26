# %% [markdown]
# <a href="https://colab.research.google.com/github/jojovputtkamer/NLP_WiSe25.26/blob/main/jputt_Transformers_SemantischSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tranformers and Semantic Search
#
# "Created by Sarah Oberbichler [![ORCID](data:image/svg+xml;base64,...)](https://orcid.org/0000-0002-1031-2759)
#
# *   Semantic search is a search engine technology that interprets the meaning of words and phrases. The results of a semantic search will return content matching the meaning of a query, as opposed to content that literally matches words in the query.
# *   Semantic search uses context clues to determine the meaning of a word across a dataset of millions of examples.
# Semantic search also identifies what other words can be used in similar contexts.

# %%
# !git clone https://github.com/soberbichler/NLP-Course4Humanities_2025.github.io.git
# Out:
# fatal: destination path 'NLP-Course4Humanities_2025.github.io' already exists and is not an empty directory.

# %%
import pandas as pd

# Replace 'your_excel_file.xlsx' with the actual path to your Excel file
df = pd.read_excel('/content/NLP-Course4Humanities_2025.github.io/datasets/newspaper_lesson.xlsx')

# Now you can work with the DataFrame 'df'
df.head()
# Out:
#                                              page_id  pagenumber  \
# 0  22IKTI2DCKL6UM6H62FNWHOG4SIHYRPY-ALTO2864623_D...           3
# 1  22O4KEI3WEZ27D2K65VLFDIONOJAZH5L-ALTO676714_DD...          10
# 2  233N6HVY2EZW3FQCMTO6HN3IXSJ2CIJA-ALTO5264456_D...           1
# 3  23D7JNHE332P6XGZZ4WW65TOCLBQDUBE-FILE_0001_DDB...           1
# 4  23ZT3TJSGVQDECCUS6SNUFPNCE5CEDUI-ALTO10636965_...           2
#
#                                          paper_title  \
# 0                    Mayener Volkszeitung. 1876-1919
# 1                            Der neue Tag. 1934-1944
# 2  Lippische Landes-Zeitung : ältestes und weitve...
# 3  Süddeutsche Zeitung : für deutsche Politik und...
# 4  Wittener Tageblatt : verbunden mit der Annener...
#
#                     provider_ddb_id  \
# 0  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 3  VNHXUCEEKHOUSYH4NVOUBHJGSRMOGK7J
# 4  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
#
#                                             provider     zdb_id  \
# 0  Universitäts- und Landesbibliothek der Rheinis...  2664084-3
# 1  Universitäts- und Landesbibliothek der Rheinis...  2927784-X
# 2  Westfälische Wilhelms-Universität Münster Univ...  2944740-9
# 3                  Württembergische Landesbibliothek  3135995-4
# 4  Westfälische Wilhelms-Universität Münster Univ...  3052283-3
#
#      publication_date                              place_of_distribution  \
# 0 1914-10-30 12:00:00                                          ['Mayen']
# 1 1938-02-26 12:00:00                                           ['Köln']
# 2 1881-06-20 12:00:00  ['Extertal', 'Horn-Bad Meinberg', 'Barntrup', ...
# 3 1915-02-19 12:00:00                                      ['Stuttgart']
# 4 1940-10-14 12:00:00                                         ['Witten']
#
#   language                             thumbnail  \
# 0  ['ger']  0fde6f1f-67cc-49a8-9c5a-b8f806e3410a
# 1  ['ger']  fb256fca-9747-4098-b1fc-a5d3b49d6ed7
# 2  ['ger']  151b36f5-1ce2-4676-9940-08260ced980a
# 3  ['ger']  2ea243ce-eb0c-4475-b64f-6ce176709aff
# 4  ['ger']  cf34ec30-f901-4dc5-b195-e577429c885f
#
#                                         pagefulltext  \
# 0  /data/altos/22/IK/22IKTI2DCKL6UM6H62FNWHOG4SIH...
# 1  /data/altos/22/O4/22O4KEI3WEZ27D2K65VLFDIONOJA...
# 2  /data/altos/23/3N/233N6HVY2EZW3FQCMTO6HN3IXSJ2...
# 3  /data/altos/23/D7/23D7JNHE332P6XGZZ4WW65TOCLBQ...
# 4  /data/altos/23/ZT/23ZT3TJSGVQDECCUS6SNUFPNCE5C...
#
#                     pagename  \
# 0   ALTO2864623_DDB_FULLTEXT
# 1    ALTO676714_DDB_FULLTEXT
# 2   ALTO5264456_DDB_FULLTEXT
# 3     FILE_0001_DDB_FULLTEXT
# 4  ALTO10636965_DDB_FULLTEXT
#
#                                    preview_reference  \
# 0  https://api.deutsche-digitale-bibliothek.de/bi...
# 1  https://api.deutsche-digitale-bibliothek.de/bi...
# 2  https://api.deutsche-digitale-bibliothek.de/bi...
# 3  https://api.deutsche-digitale-bibliothek.de/bi...
# 4  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                    plainpagefulltext
# 0  ur ein . veröfsentlicht eine # # n Kreizern ve...
# 1  Samstag , den 26 . Februar 1938 Neue sag Die D...
# 2  Die „ Lippische Landes = Zeitung " erscheint m...
# 3  enblatt für nationale Bezugspreis er durch Trä...
# 4  Dre hseder in Sonden Wiosen den Dep Großangrif...

# %%
# Installing the Sentence Tranfromers from HuggingFace
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.10.5)

# %% [markdown]
# #Using Transformers to find similar words
#
# Findig similar words is one of the most basic tasks for semantic search. While still operating on keywords, transformer models help us identify words with similar or related meanings, allowing us to broaden the scope of traditional keyword searches. This approach helps find relevant content even when exact keyword matches aren't present, by including semantically related terms in the search process.
#
# This code below implements a semantic word similarity search using the multilingual LaBSE transformer model (https://huggingface.co/sentence-transformers/LaBSE), where vector embeddings are generated dynamically based on context, unlike static word embeddings from older methods like Word2Vec. It processes a text corpus by converting all text to lowercase and removing special characters.
# The core functionality uses the transformer model to convert words into vector embeddings, then calculates cosine similarity between a target word and all other filtered words from the corpus.
#
# Cosine similarity measures the similarity between two vectors by calculating the cosine of the angle between them.

# %%
# Finde Worte, die ähnlich sind zum target_word "Lügenpresse"

import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import re
from sentence_transformers import SentenceTransformer
from collections import Counter

def preprocess_text(text):
    if pd.isna(text):
        return ""
    text = str(text).lower()
    text = re.sub(r'[^a-zäöüß\s]', '', text)
    return text

def get_unique_words(text):
    words = text.split()
    return list(set(words))

def find_similar_words(df, target_word, model, top_n=40):
    # Preprocess the text
    df['processed_text'] = df['plainpagefulltext'].apply(preprocess_text)

    # Get unique words from all texts
    all_words = []
    for text in df['processed_text']:
        all_words.extend(get_unique_words(text))

    # Get unique words and their frequencies
    word_freq = Counter(all_words)
    unique_words = list(word_freq.keys())

    print(f"Number of unique words: {len(unique_words)}")

    # Encode the target word and unique words
    target_embedding = model.encode([target_word])
    word_embeddings = model.encode(unique_words)

    # Calculate similarities
    similarities = cosine_similarity(target_embedding, word_embeddings)[0]

    # Create a DataFrame with words and their similarities
    word_sim_df = pd.DataFrame({
        'word': unique_words,
        'similarity': similarities
    })

    # Sort by similarity and get top N results
    top_similar = word_sim_df.sort_values('similarity', ascending=False).head(top_n)

    return top_similar

# Load the pre-trained multilingual model
print("Loading the sentence transformer model...")
model = SentenceTransformer('sentence-transformers/LaBSE')
print("Model loaded successfully.")

target_word = "Lügenpresse"

print(f"\nFinding words similar to '{target_word}'...")
similar_words = find_similar_words(df, target_word, model)

print("\nMost similar words:")
print(similar_words)
# Out:
# Loading the sentence transformer model...
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/804 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# 2_Dense/model.safetensors:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# Model loaded successfully.
#
# Finding words similar to 'Lügenpresse'...
# Number of unique words: 449028
#
# Most similar words:
#                       word  similarity
# 203017          lügenpress    0.937560
# 1042           lügenpresse    0.913250
# 319823         tügenpresse    0.886323
# 341981         lügenpressc    0.878414
# 375721      lügenpressecöv    0.860337
# 395917         lügenpreste    0.781827
# 89934          lügenpresie    0.780521
# 147356  lügenpressezentren    0.780405
# 377245  lügenpressefeldzug    0.779884
# 329736        lügenpresset    0.778324
# 242012   lügenpressestelle    0.776690
# 436483         lügenprrsse    0.768673
# 94200          lügcnpresse    0.762941
# 5282             lügenpree    0.743877
# 205300         lügenpreffe    0.739257
# 212027        lügenzeitung    0.737288
# 324649          lügenprefe    0.732062
# 109309         lügenprefse    0.726350
# 390143         lügenvresse    0.726303
# 116935     lügenyropaganda    0.721231
# 322153          lügenpreel    0.720182
# 275777        lllgenpresse    0.716607
# 99173         pressebetrug    0.715917
# 443047          lügenbiiro    0.710440
# 371857         lügenpritze    0.708622
# 134452         logenpresse    0.701821
# 217060       lügengazetten    0.701333
# 141944         lagenpresse    0.699228
# 413170          lügenprese    0.698853
# 44241        lügenpeitsche    0.698087
# 304002       lügengespinst    0.696438
# 391890      lügengespinste    0.694739
# 316101         lügenrausch    0.693745
# 134230           lügenbüro    0.692153
# 387531         rechtspress    0.688242
# 12827           presseluge    0.686018
# 235793          lügenbüros    0.685899
# 327758      lügenseldzuges    0.685155
# 304590    lügenbreitseiten    0.684821
# 200805     lügengespinstes    0.683974

# %% [markdown]
# # Keyword Intepended Search
#
# Unlike traditional keyword search, which would only find exact matches of words like "earthquake" or "reconstruction," semantic search understands the conceptual meaning of the entire query. For example, when searching for "reconstruction after earthquake," the system understands this as a concept involving disaster recovery, rebuilding efforts, community restoration, and infrastructure repair. This means it can identify relevant content that discusses these themes using different terminology - perhaps an article about "community revival following seismic damage" or "rebuilding homes in disaster-struck areas." The search works by transforming both the query and the searchable content into mathematical representations (vectors) that capture their meaning in a multidimensional space, where similar concepts cluster together regardless of the specific words used to express them. This allows for a more intuitive and human-like understanding of language, capturing context, synonyms, related concepts, and even cross-language connections, ultimately providing more relevant and comprehensive search results that align with the user's actual information needs.

# %% [markdown]
# ###First, let's create a context window around the words in the similar_words list

# %% [markdown]
# The code below implements a semantic search functionality using a multilingual transformer model to find relevant articles for a specific query in a dataset. It first processes and cleans the input data, then uses the SBERT (Sentence-BERT) model 'paraphrase-multilingual-MiniLM-L12-v2' to convert both the search query and all articles into numerical vectors (embeddings) that capture their semantic meaning. Using cosine similarity, it then calculates how closely each article matches the search query, assigns similarity scores, and filters out articles with scores below 0.6. The results are sorted by similarity score in descending order, and the code outputs the top 10 most relevant articles, displaying their similarity scores, titles, and the first 600 characters of their content, making it easy to identify articles that are semantically related to the reconstruction after earthquakes theme, even if they don't contain the exact search terms.

# %%
# schließt an die Similarity-Suche von "Lügenpresse" an - wird kommende Woche besprochen

def extract_context(keywords, text, tokens_before, tokens_after):
    # Ensure text is a string before processing
    if pd.isna(text):
        return ""
    text = str(text)

    # transform text to lower letters
    lower_text = text.lower()

    # find all keyword positions (case-insensitive)
    keyword_positions = []
    for keyword in keywords:
        keyword_start = lower_text.find(keyword)
        while keyword_start != -1:
            keyword_positions.append(keyword_start)
            keyword_start = lower_text.find(keyword, keyword_start + len(keyword))

    if not keyword_positions:
        return "Keywords not found in text."

    # Determine start and end of context window
    first_occurrence = min(keyword_positions)
    last_occurrence = max(keyword_positions)

    start_index = max(0, first_occurrence - tokens_before)
    end_index = min(len(text), last_occurrence + tokens_after)

    # Extract context from original text
    context = text[start_index:end_index]

    return context

# keywords
keywords = similar_words

# append context column
df['context_small'] = [extract_context(keywords, row['plainpagefulltext'], 500, 1000) for _, row in df.iterrows()]

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the transformer model
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# Query phrase for semantic search
query = "Ausländische Presse und Lügenpresse im Ausland"

# Preprocess DataFrame: drop rows where 'context_small' is NaN or not a string
if 'context_small' not in df.columns:
    raise ValueError("The column 'context_small' is missing in the DataFrame.")

# Drop rows with missing values in 'extracted_article_clean'
df = df.dropna(subset=['context_small'])

# Ensure all entries in 'extracted_article_clean' are strings
df.loc[:, 'context_small'] = df['context_small'].astype(str)

# Encode the 'extracted_article_clean' column from the DataFrame
article_embeddings = model.encode(df['context_small'].tolist(), convert_to_tensor=True)

# Encode the query
query_embedding = model.encode(query, convert_to_tensor=True)

# Calculate cosine similarity between query and each article
similarities = util.pytorch_cos_sim(query_embedding, article_embeddings)[0]

# Add similarity scores to the DataFrame
df = df.copy()  # Avoid potential chained assignment warnings
df.loc[:, 'similarity'] = similarities.cpu().numpy()

# Filter articles with similarity score > 0.6
high_similarity_df = df[df['similarity'] > 0.6].copy()

# Sort by similarity in descending order
high_similarity_df = high_similarity_df.sort_values('similarity', ascending=False)

# Print the number of articles found with similarity > 0.5
print(f"\nFound {len(high_similarity_df)} context windows with similarity score > 0.6")

# Print the top 10 highest similarity scores as examples
print("\nTop 10 highest similarity scores:")
top_10_examples = high_similarity_df.head(10)
for _, row in top_10_examples.iterrows():
    print(f"\nSimilarity Score: {row['similarity']:.4f}")
    print(f"Title: {row['paper_title']}")
    print(f"First 1000 characters of article: {row['context_small'][:1000]}...")

# Save the filtered DataFrame to a new variable
filtered_df = high_similarity_df

print(f"\nShape of filtered DataFrame: {filtered_df.shape}")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Found 58 context windows with similarity score > 0.6
#
# Top 10 highest similarity scores:
#
# Similarity Score: 0.7644
# Title: Bergedorfer Zeitung : unabhängig, überparteilich ; mit amtl. Bekanntmachungen
# First 1000 characters of article: Preſſe ſo unmittelbar in das politiſche Geſchehen eingegriffen. Niemals bis⸗ her hat die Preſſe als Faktor der internationalen Politik die Geiſter in einem ſolchen Ausmaß beſchäftigt, wie wir es heute erleben. Das politiſche Geſchehen der letzten Jahrzehnte und die Aufklärung über dieſes Geſchehen ſind ſo eng mit der Preſſe verknüpft, daß die Fragen nach der Daſeinsbe⸗ rechtigung und den Wirkungsgeſetzen der Preſſe tief in das Bewußtſein der Maſſen gedrungen ſind. Und deshalb iſt es notwendig geworden, daß wir uns hier auf dem Kongreß des Reichsparteitages mit dieſen Proble⸗ men eingehend auseinanderſetzen, daß wir die gewonnenen Erkenntniſſe ſo feſtlegen und unſerem Handeln eine ſichere Zielſetzung geben. Die Bedeutung der Preſſe im internatio⸗ nalen Leben iſt durch die phantaſtiſche Ent⸗ wicklung des modernen Verkehrs und Nach⸗ richtenweſens in ſtarkem Maße gewachſen. Das Wunder der modernen Nachrichtenox⸗ ganiſation, deren Träger die Preſſe iſt, hat die Menſchen des Eroͤballs einand...
#
# Similarity Score: 0.7359
# Title: Die Glocke. Ausgabe C. 1934-1945
# First 1000 characters of article:  Weltpresse einen entscheidenden Stoß versetzt . Ihre besten Zeiten sind vorbei , ihr trügerischer Glanz ist dahin . Diese verbrecherische demagogische Presse hat nicht nur den Fro # z der Welt zerstört , nicht nur die Völker ins Unglun gestürzt , sie hat mit diesen auch sich gestürzt . Nie mals wird sie sich wieder zu ihrer verderblichen Macht erheben können . In der Aera der libera listischen Demokratie ist die Macht der Presse im mer nur zum Schaden und zum Verhängnis der " Völker mißbraucht worden . Daß sie nun und für alle Zukunft dem Wohle und dem Glück der Völker dienen soll , so erklärte Dr . Dietrich unter stärkster Zustimmung , darin sehen wir unsere große journalisti sche Mission , für die wir den Kampf , der uns bisher zu diesem glänzenden und erfolgreichen Kongreß führte , mit aller Leidenschaft und Glut unserer Herzen weiterkämpfen werden . Im Anschluß an die Tagung waren die Teil nehmer Gäste der italienischen Regierung . Am Abend wohnten sie einer Festaufführung in der ...
#
# Similarity Score: 0.7310
# Title: Die Glocke. Ausgabe E. 1934-1945
# First 1000 characters of article: Weltpresse einen entscheidenden Stoß versetzt . Ihre besten Zeiten sind vorbei , ihr trügerischer Glanz ist dahin . Diese verbrecherische demagogische Presse hat nicht nur den Frieden der Welt zerstört , nicht nur die Völker ins Unglück gestürzt , sie hat mit diesen auch sich gestürzt . Nie mals wird sie sich wieder zu ihrer verderblichen Macht erheben können . In der Aera der libera listischen Demokratie ist die Macht der Presse im # mer nur zum Schaden und zum Verhängnis der Völker mißbraucht worden . Daß sie nun und für alle Zukunft dem Wohl ; unddem Glück der Völker dienen soll , so erstärte Dr . Dietrich unter stärkster Zustimmung , darin sehen wir unsere große journalisti sche Mission , für die wir den Kampf , der uns bisher zu diesem glänzenden und erfolgreichen Kongreß führte , mit aller Leidenschaft und Glut unserer Herzen weiterkämpfen werden . Im Anschluß an die Tagung waren die Teil nehmer Gäste der italienischen Regierung . Am Abend wohnten sie einer Festaufführung in der ...
#
# Similarity Score: 0.7108
# Title: General-Anzeiger. 1889-1945
# First 1000 characters of article: hm die Schilderung in Form von Nachrichten gemacht wird . “ Er macht auf die bezeichnende Gewohnheit in der derzeitigen USA = Presse aufmerksam , wonach die Be richte aus politischen Rechtskreisen allen Länder stets als aus tendenziöser Quelle stammend gekennzeichnet werden , während die Mitteilungen der Linken unbesehen als zuverlässig und glaubwürdig den Lesern vorgesetzt werden . Pratt berichtet uns weiter , daß nicht eine der von ihm untersuchten Lügen nachrichten von der Stelle aus datiert worden sei , wo das Ereignis hätte stattfinden müssen . Die Lüge vom „ Ausmarsch der 30000 Deutschen nach dem spanischen Kriegsschauplatz “ beispielsweise hat ein Londoner Da tum . Die Badajos = Geschichte von dem „ weißen Massen mord in den Stierkampfarena “ , wurde aus Lissabon übermittelt . Die Wiener „ Frauen mit den Plakaten um den Hals “ kam aus Prag . Die mittlerweile pein lich gewordene „ Schuschnigg = Ernennung zum Nazifüh rer “ datierte aus London . Das Märchen von der „ Deutschen Ries...
#
# Similarity Score: 0.7065
# Title: National-Zeitung : amtliches Blatt der Nationalsozialistischen Deutschen Arbeiterpartei : amtliches Kreisblatt für den Kreis Wittgenstein ; [...] ; Wittgensteiner Ausgabe
# First 1000 characters of article: ische Mordwaffen / 72 v . H . aller englischen Nachrichten sind Falschmeldungen 13 • : sen , 13 Dezember Die Rede Dr . Dietrichs vor den in Wien versammelten Journalisten der verbün en Nationen stellte eindeutig die unableugbore Heuptschuld der internationalen Hetpresse am Kriege sest Dr . Dietrich umriß zunächst die geschichtliche Entwicklung der Presse ihre Arbeit und ihre Zukunft in neuen Europa . Die Presse als geistig vernindende Krost sei zum Schrittmocher des mensch sichen Fartschritts geworden Das zweite aber war der Stellung der Presse im Zusammen jeben der Völker ihre so einzigartige Bedeutung gebe . sei ihre meinungsbildende Macht . Die Presse sei heute das politische Gehirn von Hunderten von Millionen Menschen auf dem ganzen Erdball . Das Beispiel Frankreichs Dr Dietrich setzte sich sodann mit dem Dogma der sogenannten „ Pressefreiheit " auseinander , das seit der französischen Revolution der oberste Grundsatz in der internationalen Publizistik gewesen sei . Die sogenannte ...
#
# Similarity Score: 0.7061
# Title: Münsterländische Volkszeitung : allgemeiner Anzeiger für Stadt u. Amt Rheine : Zeno-Zeitung ; [...] ; Rheiner Volksblatt
# First 1000 characters of article: m die Schilderung in Form von Nachrichten gemacht wird . “ Er macht auf die bezeichnende Gewohnheit in der derzeitigen USA = Presse aufmerksam , wonach die Berichte aus politischen Rechts kreisen aller Länder stets als aus tendenziöser Quelle stammend gekennzeichnet werden , während die Mitteilun gen der Linken unbesehen als zuverlässig und glaub würdig den Lesern vorgesetzt werden . Pratt berichtet uns weiter , daß nicht eine der von ihm untersuchten Lügennachrichten von der Stelle aus datiert worden sei , wo das Ereignis hätte stattfinden müssen . Die Lüge vom „ Ausmarsch der 30 000 Deutschen nach dem spanischen Kriegsschauplatz " beispielsweise hat ein Londoner Datum . Die Badajos = Geschichte von dem „ Weißen Massenmord in der Stierkampfarena “ wurde aus Lissabon übermittelt . Die Wiener „ Frauen mit den Plakaten um den Hals “ kamen aus Prag . Die mittler weile peinlich gewordene „ Schuschnigg = Ernennung zum Naziführer " datierte aus London . Das Märchen von der „ deutschen Riesen...
#
# Similarity Score: 0.6997
# Title: Badische Presse : Generalanzeiger der Residenz Karlsruhe und des Großherzogtums Baden
# First 1000 characters of article: mern in Zivil , von diesen Kriegsberichterstattern , die zeitweilig mehr Macht über das zukünftige Leben ihrer Mit - bürger besitzen als irgendeine andere Gruppe Menschen auf der Welt . " Und so ergeht es vielen sich demokratisch nennenden Völ - kern , in denen die sogenannte „ Pressefreiheit " das Wort , aber die Lüge das Zepter führt . So ist insbesondere auch das eben - so unverschämte wie verantwortungslose Treiben der tsche chischen Presse eine europäische Gefahrenquelle ersten Ran » ges geworden . ' nö Wahrheit soll , da « « hat die Demokratie hinsichtlich der Presse vo « M # ser Freiheit de « schamloseste « Gebranch gemacht . Es hat nie eine wirkliche Pressefreiheit gegebe « , « « d « s gibt heute keine Pressefreiheit ! Nirgendwo und i » keinem Lande der Welt . Die Presse ist immer abhä « gig n « d immer irgend jemanden verpflichtet . Es fragt sich » ur wem ! ? CB unverantwortlicher Partei - « nd Geschäftspolitik , ob den « o « nymen Mächte » des Geldes « nd der Zerstörung aller...
#
# Similarity Score: 0.6990
# Title: Die Glocke. Ausgabe D. 1939-1945
# First 1000 characters of article: n Weltpresse einen entscheidenden Stoß versetzt . Ihre besten Zeiten sind vorbei , ihr trügerischer Glanz ist dahin . Diese verbrecherische demagogische Presse hat nicht nur den Frieden der Welt zerstört , nicht nur die Völker ins Unglück gestürzt , sie hat mit diesen auch sich gestürzt . Nie mals wird sie sich wieder zu ihrer verderblichen Macht erheben können . In der Aera der libera listischen Demokratie ist die Macht der Presse im mer nur zum Schaden und zum Verhängnis der Völker mißbraucht worden . Daß sie nun und für alle Zukunft dem Wohle und dem Glück der Völker dienen soll , so erklärte Dr . Dietrich unter stärkster Zustimmung , darin sehen wir unsere große journalisti sche Mission , für die wir den Kampf , der uns bisher zu diesem glänzenden und erfolgreichen Kongreß führte , mit aller Leidenschaft und Glut unserer Herzen weiterkämpfen werden . Im Anschluß an die Tagung waren die Teil nehmer Gäste der italienischen Regierung . Am Abend wohnten sie einer Festaufführung in der ...
#
# Similarity Score: 0.6990
# Title: Die Glocke. Ausgabe F. 1936-1944
# First 1000 characters of article: n Weltpresse einen entscheidenden Stoß versetzt . Ihre besten Zeiten sind vorbei , ihr trügerischer Glanz ist dahin . Diese verbrecherische demagogische Presse hat nicht nur den Frieden der Welt zerstört , nicht nur die Völker ins Unglück gestürzt , sie hat mit diesen auch sich gestürzt . Nie mals wird sie sich wieder zu ihrer verderblichen Macht erheben können . In der Aera der libera listischen Demokratie ist die Macht der Presse im mer nur zum Schaden und zum Verhängnis der Völker mißbraucht worden . Daß sie nun und für alle Zukunft dem Wohle und dem Glück der Völker dienen soll , so erklärte Dr . Dietrich unter stärkster Zustimmung , darin sehen wir unsere große journalisti sche Mission , für die wir den Kampf , der uns bisher zu diesem glänzenden und erfolgreichen Kongreß führte , mit aller Leidenschaft und Glut unserer Herzen weiterkämpfen werden . Im Anschluß an die Tagung waren die Teil nehmer Gäste der italienischen Regierung . Am Abend wohnten sie einer Festaufführung in der ...
#
# Similarity Score: 0.6990
# Title: Die Glocke. Ausgabe B. 1934-1944
# First 1000 characters of article: n Weltpresse einen entscheidenden Stoß versetzt . Ihre besten Zeiten sind vorbei , ihr trügerischer Glanz ist dahin . Diese verbrecherische demagogische Presse hat nicht nur den Frieden der Welt zerstört , nicht nur die Völker ins Unglück gestürzt , sie hat mit diesen auch sich gestürzt . Nie mals wird sie sich wieder zu ihrer verderblichen Macht erheben können . In der Aera der libera listischen Demokratie ist die Macht der Presse im mer nur zum Schaden und zum Verhängnis der Völker mißbraucht worden . Daß sie nun und für alle Zukunft dem Wohle und dem Glück der Völker dienen soll , so erklärte Dr . Dietrich unter stärkster Zustimmung , darin sehen wir unsere große journalisti sche Mission , für die wir den Kampf , der uns bisher zu diesem glänzenden und erfolgreichen Kongreß führte , mit aller Leidenschaft und Glut unserer Herzen weiterkämpfen werden . Im Anschluß an die Tagung waren die Teil nehmer Gäste der italienischen Regierung . Am Abend wohnten sie einer Festaufführung in der ...
#
# Shape of filtered DataFrame: (58, 17)

# %%
filtered_df
# Out:
#                                                 page_id  pagenumber  \
# 269   5KSEPTR74PTASPFFTFU5PQSJZNALN6Z5-FILE_0005_DDB...           5
# 1850  T2NR3RJOJFBBRYQFSPBMSFRFAZNPRVMR-ALTO11321592_...           2
# 995   GW73VYKVMI6DJH6LQZMSIVYI4452CE3I-ALTO11272879_...           2
# 1373  M3EV6CFK5TSQCIWHL3WNTPQOOTLWMXYB-ALTO3921052_D...           6
# 598   BPR7DSFA5FDWS73QV2JJZIEDNC7NMTJF-ALTO7509518_D...           3
# 207   4WBGT4S7EC326ORYYTYUL25NBITTK3RO-ALTO799299_DD...           7
# 1239  K76GLOJEOL5M7XGHYRFYVIGZRTBLDGX5-ALTO2183535_D...           4
# 617   BWY5XSUAVZ6NWWFFZBIWMRZNJRGOJVHJ-ALTO11729019_...           2
# 421   7FWFVCWG2DCTTR6IH4IUBIXTY6HEQ6D5-ALTO11697140_...           2
# 2006  V6DJJUZQINYOTUFN6TD7ET5CNKJ7SN4T-ALTO11658437_...           2
# 296   5UI4QMKHBK65OVAMDAPNDEGOHRDSGFSX-ALTO805207_DD...           2
# 38    2HAMXXMTL4AF7YXSCRMG57F2U3CME5TV-ALTO1158203_D...           1
# 2314  ZP5ME5RUSHXHGXGKGVAXAOS4KY5QXKJJ-ALTO5750503_D...           3
# 485   A6ZQNGBJ4E4BOSQSR27FAGYNT6LPXW27-ALTO5951374_D...           2
# 554   B5LMOZ7RA5HF3TNVBVXCVFCDFJVU32RY-ALTO2349842_D...           2
# 101   3DJ3YQU5Z55X2EANJBGOFO4IARF7FZCL-ocr_1_DDB_FUL...           1
# 1867  TBQZJUZLLSTOZIKJSF4SBQUYZBSSBTXU-FILE_0011_DDB...          11
# 2288  Z6QRTSCJUTEZ52D73K2TC4YB7EQ3QK6F-ALTO5978600_D...           2
# 2242  YKH7ZYFUAZ6VMVCZHWYQIBP6RUIVFHYZ-ALTO3299848_D...           1
# 2191  XSYX7SHUM32PCSOND6XBK26YTGEGDRBY-ALTO5397775_D...           1
# 1372  M3EV6CFK5TSQCIWHL3WNTPQOOTLWMXYB-ALTO3921049_D...           3
# 854   EYN3CHS2ATIP2LUMFQHEN23YQ7TFE2BW-ALTO110059_DD...           1
# 2118  WTCXKNREZ2ZIJZQUFHUORI3WPERLQBJR-ALTO6822164_D...           1
# 862   F5TFBTHFDII7NE55MRSFVN6IC3V7ISH4-ALTO4156961_D...           1
# 1956  UJY3TEPL2WKXQ7FBMTQPEWUGLZ6YVUUJ-ALTO469418_DD...           2
# 351   6JHRBHBNRI3NJGOJ2KJNDPRVW6VV7E32-ALTO2149515_D...           1
# 368   6RIPPWLJXU4UOSE477PHNHLD34TYSIGD-fulltext_9_DD...           9
# 594   BOMJCMXKMPKPNYTCMDSBAK6N7GEZEYRB-ALTO3931166_D...           2
# 700   D22BUTVUVTGSOPO34WNQ5Z4PBQWOJY4G-ALTO8631168_D...           8
# 32    2F7H4QGGAZBBOP2VN6SREXSP5H6SJ6B4-uuid-d95cdd63...           6
# 873   FCSJEHTSJMG2YNRIPJKZ27HE54A4PDVP-ALTO6936055_D...           1
# 234   56K3P4RCQSNET6XEDWQDNERKTPC2RQ4O-ALTO17111389_...           9
# 59    2PGNKXI4VARBXPFY7ISXZBMI24VAJM6E-ALTO6689525_D...           3
# 2071  W5WTAHHD5XHSCF4UXZ4V3UPLDBXV6HS2-ALTO7971953_D...           6
# 1232  K4MP4TQT6GVN7BDSDDSHWRRMZP4K6XTC-ALTO684169_DD...           6
# 1214  JTCQAXGW7XJ4A6WNIRYCVTDKI4OL6I3C-uuid-f97d5a28...           5
# 453   7UOXGELUDBHQ7BKIP5GTGAEZNXQND3HZ-ALTO3779315_D...           3
# 2260  YS46GFCWZBE3LH2J3F2YSLAZD7HB47QY-ALTO614344_DD...           3
# 242   5D4HTTIB2QC3WHMLA5TNUBP7SUL5Z7LO-FILE_0005_DDB...           5
# 1141  IXNBBG6HUB55HJR7CNWOZYZ4OXSVOYY4-ALTO7742098_D...           2
# 1525  OEFVM4G22PJHFI42A4JA34Y5COJ4JYYI-ALTO17110799_...           3
# 715   DB6YP2TUGDYYDPHZKTLNUDGY2CWBCKIL-ALTO11376848_...           1
# 859   F3KRK4LU23GJTGFGGIR5LID7DOMEHD4O-ALTO1725342_D...           1
# 1095  ID72HZMIG6Q46N4F6SJFM4YRFRHGSSX6-uuid-e6b2294c...           5
# 405   77A6ONP6YM653YEDPPMFXYJCVNZ6DO6Q-ALTO10934162_...           2
# 1909  TTPJ67X6KR3PK567GGSRFI7Z2TI3S55A-ALTO3013164_D...          13
# 2239  YKC7NXF24PIYHLID6FW5OATRE2PDG5WC-ALTO389057_DD...           1
# 936   G6SHSV5THFRJVU5GXRSLH26RJBXAIMRI-ALTO4950657_D...           2
# 428   7INTBSXJCADUXZWQJVB3PUN36LXX5SXG-ALTO12419294_...           2
# 993   GVI6GNNG5OCA343YF45ZR7WGSDIAHVTQ-ALTO1496866_D...           7
# 1973  UPC4PWLVZ6OOCV5H7QRSFPTI6WBVLYYK-FILE_0006_ALT...           6
# 155   46KLQ4OEB4IMXOGBRGNW44NAFZU364IC-ALTO1066142_D...           6
# 71    2TS2IX7YES3NRJTGVH3O5B43S7STISEP-ALTO843489_DD...           2
# 31    2EVWG7RM6A23DDEN2GQR3N4Q2V54QX6C-ALTO801216_DD...           2
# 984   GRLLVKAVWWY7OFRCMPZTVG73EUA4YDI7-ALTO3447551_D...           2
# 1223  JZ5L5YL74N3OBBQ67TNPTBNZQD46NV2P-ALTO7712030_D...           4
# 1309  LD6HK2Y2MTSJ6KGHQVYUFUIMOAHSTOME-ALTO11759921_...           7
# 139   3VGIM2NVXPF776YKLS4O5TQTYANXQWSE-ALTO9193918_D...           8
#
#                                             paper_title  \
# 269   Bergedorfer Zeitung : unabhängig, überparteili...
# 1850                   Die Glocke. Ausgabe C. 1934-1945
# 995                    Die Glocke. Ausgabe E. 1934-1945
# 1373                        General-Anzeiger. 1889-1945
# 598   National-Zeitung : amtliches Blatt der Nationa...
# 207   Münsterländische Volkszeitung : allgemeiner An...
# 1239  Badische Presse : Generalanzeiger der Residenz...
# 617                    Die Glocke. Ausgabe D. 1939-1945
# 421                    Die Glocke. Ausgabe F. 1936-1944
# 2006                   Die Glocke. Ausgabe B. 1934-1944
# 296   Westfälische Tageszeitung : amtl. Organ des Ga...
# 38                        Dortmunder Zeitung. 1874-1939
# 2314  Münsterischer Anzeiger : Westfälischer Merkur ...
# 485                        Bochumer Anzeiger. 1934-1944
# 554        Westfälische Zeitung : Bielefelder Tageblatt
# 101                                            Vorwärts
# 1867                 Harburger Anzeigen und Nachrichten
# 2288                       Bochumer Anzeiger. 1934-1944
# 2242         Mittelrheinische Landes-Zeitung. 1934-1939
# 2191  Sauerländisches Volksblatt : aeltester Anzeige...
# 1372                        General-Anzeiger. 1889-1945
# 854   Schwerter Zeitung : Heimatblatt für die Stadt ...
# 2118  Stadtanzeiger für Castrop-Rauxel und Umgebung ...
# 862                          Bergische Wacht. 1907-1941
# 1956  Neckar-Bote : Heimatzeitung für Seckenheim und...
# 351          Mittelrheinische Landes-Zeitung. 1934-1941
# 368   Berliner Börsen-Zeitung : Tageszeitung für Pol...
# 594                         General-Anzeiger. 1889-1945
# 700                           Bergische Post. 1924-1941
# 32    Eibenstocker Tageblatt : Anzeiger für den Amts...
# 873   Aachener Anzeiger : politisches Tageblatt : be...
# 234           Mitteldeutschland ; [...] ; Saale-Zeitung
# 59    Rhein- und Ruhrzeitung : Tageszeitung für das ...
# 2071                      Bergheimer Zeitung. 1905-1943
# 1232                            Der neue Tag. 1934-1944
# 1214  Hohenstein-Ernstthaler Tageblatt und Anzeiger ...
# 453                    Honnefer Volkszeitung. 1889-1978
# 2260  Viernheimer Volkszeitung : Amtsblatt der Bürge...
# 242                                               Verbo
# 1141  General-Anzeiger für das rheinisch-westfälisch...
# 1525          Mitteldeutschland ; [...] ; Saale-Zeitung
# 715                 Bergische Landes-Zeitung. 1931-1945
# 859                           Haaner Zeitung. 1928-1941
# 1095  Frankenberger Tageblatt, Bezirks-Anzeiger : Am...
# 405                        Kölnische Zeitung. 1803-1945
# 1909  Rheinisch-Bergische Zeitung : Heidersche Zeitu...
# 2239  Neue Mannheimer Zeitung : NMZ : Mannheimer Neu...
# 936   Durlacher Tagblatt : Heimatblatt für die Stadt...
# 428   Dorstener Volkszeitung und Wochenblatt. 1910-1919
# 993   Velberter Zeitung : Nevigeser Volkszeitung : H...
# 1973  Deutscher Reichsanzeiger und Preußischer Staat...
# 155   Jeversches Wochenblatt : Friesisches Tageblatt...
# 71                    Bünder Generalanzeiger. 1938-1938
# 31    Münsterländische Volkszeitung : allgemeiner An...
# 984   Aachener allgemeine Zeitung : liberale Bürgerz...
# 1223  General-Anzeiger für das rheinisch-westfälisch...
# 1309                              Die Glocke. 1885-1933
# 139                        Kölnische Zeitung. 1803-1945
#
#                        provider_ddb_id  \
# 269   BZVTR553HLJBDMQD5NCJ6YKP3HMBQRF4
# 1850  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 995   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 1373  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 598   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 207   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 1239  INLVDM4I3AMZLTG6AE6C5GZRJKGOF75K
# 617   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 421   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 2006  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 296   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 38    4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 2314  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 485   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 554   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 101   CZTZO4SBNHW34JVKYRWW67725WWGLZA5
# 1867  BZVTR553HLJBDMQD5NCJ6YKP3HMBQRF4
# 2288  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 2242  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2191  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 1372  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 854   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 2118  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 862   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1956  NWNEPSPSGSSYWU3IP75BYGGBRNQORN6A
# 351   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 368   6GFV3I4ELFEEFQIN2WECOXMTI5FUWHCK
# 594   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 700   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 32    265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 873   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 234   Q5Q6S6XOPTGP3BUM4I2JNP7V53BAWOTT
# 59    VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2071  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1232  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1214  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 453   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2260  RMHO6ZMQPXRNLKEUNW3VG2B563ALDO5S
# 242   VNHXUCEEKHOUSYH4NVOUBHJGSRMOGK7J
# 1141  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1525  Q5Q6S6XOPTGP3BUM4I2JNP7V53BAWOTT
# 715   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 859   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1095  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 405   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1909  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2239  NWNEPSPSGSSYWU3IP75BYGGBRNQORN6A
# 936   INLVDM4I3AMZLTG6AE6C5GZRJKGOF75K
# 428   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 993   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1973  NEOOVZ6BJZD3LYNKU3N7PFT6VD54SMMG
# 155   56EXT7QNQMRDQY4ZZWQGOLXGR3IN3C4F
# 71    4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 31    4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 984   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1223  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1309  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 139   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
#
#                                                provider     zdb_id  \
# 269   Staats- und Universitätsbibliothek Hamburg Car...  2918916-0
# 1850  Westfälische Wilhelms-Universität Münster Univ...  3091233-7
# 995   Westfälische Wilhelms-Universität Münster Univ...  3091581-8
# 1373  Universitäts- und Landesbibliothek der Rheinis...  2815866-0
# 598   Westfälische Wilhelms-Universität Münster Univ...  3075393-4
# 207   Westfälische Wilhelms-Universität Münster Univ...  2935918-1
# 1239                          Badische Landesbibliothek  2797055-3
# 617   Westfälische Wilhelms-Universität Münster Univ...  3092133-8
# 421   Westfälische Wilhelms-Universität Münster Univ...  3092222-7
# 2006  Westfälische Wilhelms-Universität Münster Univ...  3092144-2
# 296   Westfälische Wilhelms-Universität Münster Univ...  2935999-5
# 38    Westfälische Wilhelms-Universität Münster Univ...  2941861-6
# 2314  Westfälische Wilhelms-Universität Münster Univ...  2988513-9
# 485   Westfälische Wilhelms-Universität Münster Univ...  2998384-8
# 554   Westfälische Wilhelms-Universität Münster Univ...  2973670-5
# 101             Bibliothek der Friedrich-Ebert-Stiftung  2814128-3
# 1867  Staats- und Universitätsbibliothek Hamburg Car...  2918901-9
# 2288  Westfälische Wilhelms-Universität Münster Univ...  2998384-8
# 2242  Universitäts- und Landesbibliothek der Rheinis...  2753470-4
# 2191  Westfälische Wilhelms-Universität Münster Univ...  2983003-5
# 1372  Universitäts- und Landesbibliothek der Rheinis...  2815866-0
# 854   Westfälische Wilhelms-Universität Münster Univ...  2929582-8
# 2118  Westfälische Wilhelms-Universität Münster Univ...  2984777-1
# 862   Universitäts- und Landesbibliothek der Rheinis...  2581956-2
# 1956                                 MARCHIVUM Mannheim  3137970-9
# 351   Universitäts- und Landesbibliothek der Rheinis...  2930056-3
# 368   Staatsbibliothek zu Berlin - Preußischer Kultu...  2436020-X
# 594   Universitäts- und Landesbibliothek der Rheinis...  2815866-0
# 700   Universitäts- und Landesbibliothek der Rheinis...  3025036-5
# 32    Sächsische Landesbibliothek - Staats- und Univ...  2814605-0
# 873   Universitäts- und Landesbibliothek der Rheinis...  2975858-0
# 234   Martin-Luther-Universität Halle-Wittenberg, Un...  3000035-X
# 59    Universitäts- und Landesbibliothek der Rheinis...  2971362-6
# 2071  Universitäts- und Landesbibliothek der Rheinis...  2998037-9
# 1232  Universitäts- und Landesbibliothek der Rheinis...  2927784-X
# 1214  Sächsische Landesbibliothek - Staats- und Univ...  3155690-5
# 453   Universitäts- und Landesbibliothek der Rheinis...  2835548-9
# 2260                              Stadtarchiv Viernheim  3167336-3
# 242                   Württembergische Landesbibliothek  3128556-9
# 1141  Universitäts- und Landesbibliothek der Rheinis...  2983920-8
# 1525  Martin-Luther-Universität Halle-Wittenberg, Un...  3000035-X
# 715   Universitäts- und Landesbibliothek der Rheinis...  3055590-5
# 859   Universitäts- und Landesbibliothek der Rheinis...  2929067-3
# 1095  Sächsische Landesbibliothek - Staats- und Univ...  3107204-5
# 405   Universitäts- und Landesbibliothek der Rheinis...  2719361-5
# 1909  Universitäts- und Landesbibliothek der Rheinis...  2696929-4
# 2239                                 MARCHIVUM Mannheim  3111617-6
# 936                           Badische Landesbibliothek  2919519-6
# 428   Westfälische Wilhelms-Universität Münster Univ...  3092563-0
# 993   Universitäts- und Landesbibliothek der Rheinis...  2932176-1
# 1973       Universität Mannheim. Universitätsbibliothek  2851723-4
# 155                          Landesbibliothek Oldenburg   824611-7
# 71    Westfälische Wilhelms-Universität Münster Univ...  2940954-8
# 31    Westfälische Wilhelms-Universität Münster Univ...  2935918-1
# 984   Universitäts- und Landesbibliothek der Rheinis...  2777345-0
# 1223  Universitäts- und Landesbibliothek der Rheinis...  2983920-8
# 1309  Westfälische Wilhelms-Universität Münster Univ...  2969917-4
# 139   Universitäts- und Landesbibliothek der Rheinis...  2719361-5
#
#         publication_date                              place_of_distribution  \
# 269  1938-09-09 12:00:00  ['Hamburg', 'Hamburg-Bergedorf', 'Bergedorf', ...
# 1850 1942-04-13 12:00:00                                      ['Gütersloh']
# 995  1942-04-13 12:00:00                              ['Kreis Wiedenbrück']
# 1373 1938-09-09 12:00:00  ['Bonn', 'Bad Godesberg', 'Siegburg', 'Euskirc...
# 598  1941-12-13 12:00:00                         ['Landkreis Wittgenstein']
# 207  1938-09-09 12:00:00                                         ['Rheine']
# 1239 1938-09-09 12:00:00                                      ['Karlsruhe']
# 617  1942-04-13 12:00:00                                      ['Warendorf']
# 421  1942-04-13 12:00:00                        ['Ahlen (Kreis Warendorf)']
# 2006 1942-04-13 12:00:00                                         ['Beckum']
# 296  1940-10-13 12:00:00                                ['Münster (Westf)']
# 38   1938-09-08 12:00:00                                       ['Dortmund']
# 2314 1938-09-09 12:00:00             ['Münster (Westf)', 'Ahaus', 'Beckum']
# 485  1935-08-05 12:00:00                                         ['Bochum']
# 554  1938-09-09 12:00:00                                      ['Bielefeld']
# 101  1909-08-12 12:00:00                                         ['Berlin']
# 1867 1942-04-13 12:00:00  ['Hamburg-Harburg', 'Hamburg', 'Harburg (Elbe)...
# 2288 1942-04-13 12:00:00                                         ['Bochum']
# 2242 1938-09-09 12:00:00                                           ['Bonn']
# 2191 1938-09-09 12:00:00        ['Olpe', 'Attendorn', 'Finnentrop', 'Olpe']
# 1372 1938-09-09 12:00:00  ['Bonn', 'Bad Godesberg', 'Siegburg', 'Euskirc...
# 854  1938-09-09 12:00:00  ['Schwerte', 'Westhofen (Kreis Iserlohn)', 'Sc...
# 2118 1938-09-09 12:00:00                     ['Castrop-Rauxel', 'Dortmund']
# 862  1938-09-09 12:00:00  ['Klüppelberg', 'Wipperfürth', 'Wipperfürth-Kl...
# 1956 1938-09-09 12:00:00  ['Seckenheim', 'Mannheim', 'Mannheim-Seckenhei...
# 351  1938-09-09 12:00:00                                  ['Bad Godesberg']
# 368  1923-02-11 12:00:00                                         ['Berlin']
# 594  1942-04-11 12:00:00  ['Bonn', 'Bad Godesberg', 'Siegburg', 'Euskirc...
# 700  1938-09-14 12:00:00  ['Kreis Solingen', 'Rhein-Wupper-Kreis', 'Opla...
# 32   1938-09-09 12:00:00  ['Eibenstock', 'Eibenstock-Blauenthal', 'Carls...
# 873  1942-04-17 12:00:00              ['Aachen', 'Regierungsbezirk Aachen']
# 234  1938-10-19 12:00:00                                  ['Halle (Saale)']
# 59   1938-09-09 12:00:00  ['Duisburg', 'Mülheim an der Ruhr', 'Ruhrort',...
# 2071 1915-07-24 12:00:00                                ['Bergheim (Erft)']
# 1232 1938-09-09 12:00:00                                           ['Köln']
# 1214 1938-09-12 12:00:00  ['Hohenstein-Ernstthal', 'Oberlungwitz', 'Gers...
# 453  1938-09-10 12:00:00                                     ['Bad Honnef']
# 2260 1938-06-22 12:00:00                                      ['Viernheim']
# 242  1938-09-09 12:00:00                       ['Riedlingen', 'Bad Buchau']
# 1141 1941-12-13 12:00:00  ['Duisburg', 'Hamborn', 'Duisburg-Hamborn', 'M...
# 1525 1938-09-09 12:00:00                                  ['Halle (Saale)']
# 715  1938-09-10 12:00:00                                   ['Radevormwald']
# 859  1938-09-10 12:00:00                                           ['Haan']
# 1095 1941-12-15 12:00:00                       ['Frankenberg/Sa.', 'Flöha']
# 405  1942-04-13 12:00:00          ['Köln', 'Kleve (Kreis Kleve)', 'Jülich']
# 1909 1938-09-10 12:00:00  ['Bergisch Gladbach', 'Bensberg', 'Wipperfürth...
# 2239 1935-09-28 12:00:00                                       ['Mannheim']
# 936  1941-12-13 12:00:00                                        ['Durlach']
# 428  1914-11-04 12:00:00                                        ['Dorsten']
# 993  1938-09-08 12:00:00  ['Velbert', 'Velbert-Langenberg', 'Heiligenhau...
# 1973 1933-03-24 12:00:00                                         ['Berlin']
# 155  1938-09-09 12:00:00                                          ['Jever']
# 71   1938-02-28 12:00:00             ['Bünde', 'Bünde-Ennigloh', 'Herford']
# 31   1939-03-23 12:00:00                                         ['Rheine']
# 984  1901-05-31 12:00:00                                         ['Aachen']
# 1223 1938-09-09 12:00:00  ['Duisburg', 'Hamborn', 'Duisburg-Hamborn', 'M...
# 1309 1916-06-17 12:00:00  ['Oelde', 'Ahlen (Kreis Warendorf)', 'Beckum',...
# 139  1915-07-01 12:00:00          ['Köln', 'Kleve (Kreis Kleve)', 'Jülich']
#
#      language                             thumbnail  \
# 269   ['ger']  b1c14067-9b8c-45f1-8d54-66d2441ed5cd
# 1850  ['ger']  b600ada8-a44f-4ea0-84e9-0a1c2b08a9d4
# 995   ['ger']  41792f5b-d49a-42bf-ba91-c804cc3b22ae
# 1373  ['ger']  72053681-f679-49a3-bcff-5b533ca45647
# 598   ['ger']  501826b5-e94e-4d9c-bd20-2c3a70d5db4b
# 207   ['ger']  83927933-c2aa-467b-b8af-bc33aa2bec8a
# 1239  ['ger']  85eef2fd-cea1-473f-a561-9a4990bb77c9
# 617   ['ger']  e9f2a263-25d6-4368-9137-f92ee0dab429
# 421   ['ger']  190a6212-bc9e-4680-9e92-69331d4a0437
# 2006  ['ger']  2d323b70-a4f7-446f-933a-8fb03e47888c
# 296   ['ger']  ec04360a-7362-468e-b592-2ab977e60c56
# 38    ['ger']  ca65ac68-deb1-48b6-be18-b47443079703
# 2314  ['ger']  e9538a75-9013-4fa5-a940-a75cf89d884d
# 485   ['ger']  e16c7c95-47f9-49d1-b08e-7282f194f7fc
# 554   ['ger']  8d5e21a5-27a9-448e-a1a9-5e732e52b0c9
# 101   ['ger']  f8d2752a-8a34-4b46-a5fa-7ed7fc7bbbf0
# 1867  ['ger']  af97117a-b1cd-411a-ad9a-dfcfe2a4cbab
# 2288  ['ger']  3654017e-a540-4537-b79c-f181d7fa30dd
# 2242  ['ger']  00063088-17b2-47ab-a31a-c6ce866dec0a
# 2191  ['ger']  98f9ef76-de4c-40f7-8ed1-b0d4570bbfe4
# 1372  ['ger']  72053681-f679-49a3-bcff-5b533ca45647
# 854   ['ger']  07d1c2a7-2397-4ee2-af39-388372c9e19d
# 2118  ['ger']  36603893-2b5f-481c-9a60-841b34cbc6cf
# 862   ['ger']  15e4197f-3b1e-49ec-842c-ec065c299439
# 1956  ['ger']  f90f13d2-954a-4753-9daa-942dcdf24ad7
# 351   ['ger']  90a4e24e-56b5-42e8-8a64-2d4c1afbcafd
# 368   ['ger']  19801667-9057-4a78-bedf-c94479867c42
# 594   ['ger']  da985981-8fe6-461d-b06e-9c61cb030d72
# 700   ['ger']  34df76b0-5fa5-456c-945f-7b8baf86203e
# 32    ['ger']  9325cab8-ce84-4060-8de7-487c547feea7
# 873   ['ger']  ef2d409c-a1ec-46f7-acd3-19be7862f8c8
# 234   ['ger']  3046939b-9e2a-4aa5-af1a-30eadc2025f8
# 59    ['ger']  9386de61-884c-4d7e-bfc1-09c5b56ba3e1
# 2071  ['ger']  db0306d7-5a1e-4fc0-869b-6b00712142ce
# 1232  ['ger']  3d91f6c8-6ebf-45c2-a6d9-b6be20d6b34d
# 1214  ['ger']  11fe4fe6-f809-4966-9a5b-e88ec47699b6
# 453   ['ger']  edbe5b6a-2db7-4916-879f-050664483ebb
# 2260  ['ger']  faeaf85a-eefa-4ab5-a323-e216bf1b3b49
# 242   ['ger']  3cefe8fb-940f-4783-a726-49ec023ced85
# 1141  ['ger']  c99cdf81-a64e-4916-9aed-46a9ea0be3e0
# 1525  ['ger']  b072b343-6757-4140-a0ea-f6b1c347116e
# 715   ['ger']  35a66bd8-fe6d-4818-8718-406a4318aad4
# 859   ['ger']  a954240e-d703-4c15-b228-428e7fbc4b23
# 1095  ['ger']  2a06150f-7528-4a08-847a-b988f3f07325
# 405   ['ger']  16117541-cad7-4618-b147-10985ae0ed8c
# 1909  ['ger']  7d1f431f-8fe9-41ba-98ac-92b2aa8b10d2
# 2239  ['ger']  0240794d-91e8-4465-b208-014444cfe106
# 936   ['ger']  0d83bc51-4aac-4302-8701-d58635348c49
# 428   ['ger']  66556f47-bbba-4c3a-802c-79f535b5d931
# 993   ['ger']  b54c0020-af59-43d7-92f0-0ade6d18f7d7
# 1973  ['ger']  1eb2a0bc-df3c-40d4-a583-ca2e568cae6d
# 155   ['ger']  260db11a-2554-4b9d-b31f-44938d38301f
# 71    ['ger']  43c3e6b2-4869-4d0f-a8e5-8ee866b9b5a9
# 31    ['ger']  a2134a62-f910-440c-88b1-ef50344fd987
# 984   ['ger']  ff14c339-16ec-45c9-ac3e-e734b46f0361
# 1223  ['ger']  63d7c6bf-a860-4ae3-9467-179f2000d996
# 1309  ['ger']  081ed711-ffc3-4af9-9cca-5d9fde613f9b
# 139   ['ger']  6c762a51-d1ab-4ee2-9cf2-25f5bdd2218a
#
#                                            pagefulltext  \
# 269   /data/altos/5K/SE/5KSEPTR74PTASPFFTFU5PQSJZNAL...
# 1850  /data/altos/T2/NR/T2NR3RJOJFBBRYQFSPBMSFRFAZNP...
# 995   /data/altos/GW/73/GW73VYKVMI6DJH6LQZMSIVYI4452...
# 1373  /data/altos/M3/EV/M3EV6CFK5TSQCIWHL3WNTPQOOTLW...
# 598   /data/altos/BP/R7/BPR7DSFA5FDWS73QV2JJZIEDNC7N...
# 207   /data/altos/4W/BG/4WBGT4S7EC326ORYYTYUL25NBITT...
# 1239  /data/altos/K7/6G/K76GLOJEOL5M7XGHYRFYVIGZRTBL...
# 617   /data/altos/BW/Y5/BWY5XSUAVZ6NWWFFZBIWMRZNJRGO...
# 421   /data/altos/7F/WF/7FWFVCWG2DCTTR6IH4IUBIXTY6HE...
# 2006  /data/altos/V6/DJ/V6DJJUZQINYOTUFN6TD7ET5CNKJ7...
# 296   /data/altos/5U/I4/5UI4QMKHBK65OVAMDAPNDEGOHRDS...
# 38    /data/altos/2H/AM/2HAMXXMTL4AF7YXSCRMG57F2U3CM...
# 2314  /data/altos/ZP/5M/ZP5ME5RUSHXHGXGKGVAXAOS4KY5Q...
# 485   /data/altos/A6/ZQ/A6ZQNGBJ4E4BOSQSR27FAGYNT6LP...
# 554   /data/altos/B5/LM/B5LMOZ7RA5HF3TNVBVXCVFCDFJVU...
# 101   /data/altos/3D/J3/3DJ3YQU5Z55X2EANJBGOFO4IARF7...
# 1867  /data/altos/TB/QZ/TBQZJUZLLSTOZIKJSF4SBQUYZBSS...
# 2288  /data/altos/Z6/QR/Z6QRTSCJUTEZ52D73K2TC4YB7EQ3...
# 2242  /data/altos/YK/H7/YKH7ZYFUAZ6VMVCZHWYQIBP6RUIV...
# 2191  /data/altos/XS/YX/XSYX7SHUM32PCSOND6XBK26YTGEG...
# 1372  /data/altos/M3/EV/M3EV6CFK5TSQCIWHL3WNTPQOOTLW...
# 854   /data/altos/EY/N3/EYN3CHS2ATIP2LUMFQHEN23YQ7TF...
# 2118  /data/altos/WT/CX/WTCXKNREZ2ZIJZQUFHUORI3WPERL...
# 862   /data/altos/F5/TF/F5TFBTHFDII7NE55MRSFVN6IC3V7...
# 1956  /data/altos/UJ/Y3/UJY3TEPL2WKXQ7FBMTQPEWUGLZ6Y...
# 351   /data/altos/6J/HR/6JHRBHBNRI3NJGOJ2KJNDPRVW6VV...
# 368   /data/altos/6R/IP/6RIPPWLJXU4UOSE477PHNHLD34TY...
# 594   /data/altos/BO/MJ/BOMJCMXKMPKPNYTCMDSBAK6N7GEZ...
# 700   /data/altos/D2/2B/D22BUTVUVTGSOPO34WNQ5Z4PBQWO...
# 32    /data/altos/2F/7H/2F7H4QGGAZBBOP2VN6SREXSP5H6S...
# 873   /data/altos/FC/SJ/FCSJEHTSJMG2YNRIPJKZ27HE54A4...
# 234   /data/altos/56/K3/56K3P4RCQSNET6XEDWQDNERKTPC2...
# 59    /data/altos/2P/GN/2PGNKXI4VARBXPFY7ISXZBMI24VA...
# 2071  /data/altos/W5/WT/W5WTAHHD5XHSCF4UXZ4V3UPLDBXV...
# 1232  /data/altos/K4/MP/K4MP4TQT6GVN7BDSDDSHWRRMZP4K...
# 1214  /data/altos/JT/CQ/JTCQAXGW7XJ4A6WNIRYCVTDKI4OL...
# 453   /data/altos/7U/OX/7UOXGELUDBHQ7BKIP5GTGAEZNXQN...
# 2260  /data/altos/YS/46/YS46GFCWZBE3LH2J3F2YSLAZD7HB...
# 242   /data/altos/5D/4H/5D4HTTIB2QC3WHMLA5TNUBP7SUL5...
# 1141  /data/altos/IX/NB/IXNBBG6HUB55HJR7CNWOZYZ4OXSV...
# 1525  /data/altos/OE/FV/OEFVM4G22PJHFI42A4JA34Y5COJ4...
# 715   /data/altos/DB/6Y/DB6YP2TUGDYYDPHZKTLNUDGY2CWB...
# 859   /data/altos/F3/KR/F3KRK4LU23GJTGFGGIR5LID7DOME...
# 1095  /data/altos/ID/72/ID72HZMIG6Q46N4F6SJFM4YRFRHG...
# 405   /data/altos/77/A6/77A6ONP6YM653YEDPPMFXYJCVNZ6...
# 1909  /data/altos/TT/PJ/TTPJ67X6KR3PK567GGSRFI7Z2TI3...
# 2239  /data/altos/YK/C7/YKC7NXF24PIYHLID6FW5OATRE2PD...
# 936   /data/altos/G6/SH/G6SHSV5THFRJVU5GXRSLH26RJBXA...
# 428   /data/altos/7I/NT/7INTBSXJCADUXZWQJVB3PUN36LXX...
# 993   /data/altos/GV/I6/GVI6GNNG5OCA343YF45ZR7WGSDIA...
# 1973  /data/altos/UP/C4/UPC4PWLVZ6OOCV5H7QRSFPTI6WBV...
# 155   /data/altos/46/KL/46KLQ4OEB4IMXOGBRGNW44NAFZU3...
# 71    /data/altos/2T/S2/2TS2IX7YES3NRJTGVH3O5B43S7ST...
# 31    /data/altos/2E/VW/2EVWG7RM6A23DDEN2GQR3N4Q2V54...
# 984   /data/altos/GR/LL/GRLLVKAVWWY7OFRCMPZTVG73EUA4...
# 1223  /data/altos/JZ/5L/JZ5L5YL74N3OBBQ67TNPTBNZQD46...
# 1309  /data/altos/LD/6H/LD6HK2Y2MTSJ6KGHQVYUFUIMOAHS...
# 139   /data/altos/3V/GI/3VGIM2NVXPF776YKLS4O5TQTYANX...
#
#                                                pagename  \
# 269                              FILE_0005_DDB_FULLTEXT
# 1850                          ALTO11321592_DDB_FULLTEXT
# 995                           ALTO11272879_DDB_FULLTEXT
# 1373                           ALTO3921052_DDB_FULLTEXT
# 598                            ALTO7509518_DDB_FULLTEXT
# 207                             ALTO799299_DDB_FULLTEXT
# 1239                           ALTO2183535_DDB_FULLTEXT
# 617                           ALTO11729019_DDB_FULLTEXT
# 421                           ALTO11697140_DDB_FULLTEXT
# 2006                          ALTO11658437_DDB_FULLTEXT
# 296                             ALTO805207_DDB_FULLTEXT
# 38                             ALTO1158203_DDB_FULLTEXT
# 2314                           ALTO5750503_DDB_FULLTEXT
# 485                            ALTO5951374_DDB_FULLTEXT
# 554                            ALTO2349842_DDB_FULLTEXT
# 101                                  ocr_1_DDB_FULLTEXT
# 1867                             FILE_0011_DDB_FULLTEXT
# 2288                           ALTO5978600_DDB_FULLTEXT
# 2242                           ALTO3299848_DDB_FULLTEXT
# 2191                           ALTO5397775_DDB_FULLTEXT
# 1372                           ALTO3921049_DDB_FULLTEXT
# 854                             ALTO110059_DDB_FULLTEXT
# 2118                           ALTO6822164_DDB_FULLTEXT
# 862                            ALTO4156961_DDB_FULLTEXT
# 1956                            ALTO469418_DDB_FULLTEXT
# 351                            ALTO2149515_DDB_FULLTEXT
# 368                             fulltext_9_DDB_FULLTEXT
# 594                            ALTO3931166_DDB_FULLTEXT
# 700                            ALTO8631168_DDB_FULLTEXT
# 32    uuid-d95cdd63-9533-490b-aa0e-0d88fc9645f1_DDB_...
# 873                            ALTO6936055_DDB_FULLTEXT
# 234                           ALTO17111389_DDB_FULLTEXT
# 59                             ALTO6689525_DDB_FULLTEXT
# 2071                           ALTO7971953_DDB_FULLTEXT
# 1232                            ALTO684169_DDB_FULLTEXT
# 1214  uuid-f97d5a28-0fb0-4925-acda-5e53ce624d98_DDB_...
# 453                            ALTO3779315_DDB_FULLTEXT
# 2260                            ALTO614344_DDB_FULLTEXT
# 242                              FILE_0005_DDB_FULLTEXT
# 1141                           ALTO7742098_DDB_FULLTEXT
# 1525                          ALTO17110799_DDB_FULLTEXT
# 715                           ALTO11376848_DDB_FULLTEXT
# 859                            ALTO1725342_DDB_FULLTEXT
# 1095  uuid-e6b2294c-c529-4ee0-a397-e3e21c6234b8_DDB_...
# 405                           ALTO10934162_DDB_FULLTEXT
# 1909                           ALTO3013164_DDB_FULLTEXT
# 2239                            ALTO389057_DDB_FULLTEXT
# 936                            ALTO4950657_DDB_FULLTEXT
# 428                           ALTO12419294_DDB_FULLTEXT
# 993                            ALTO1496866_DDB_FULLTEXT
# 1973                        FILE_0006_ALTO_DDB_FULLTEXT
# 155                            ALTO1066142_DDB_FULLTEXT
# 71                              ALTO843489_DDB_FULLTEXT
# 31                              ALTO801216_DDB_FULLTEXT
# 984                            ALTO3447551_DDB_FULLTEXT
# 1223                           ALTO7712030_DDB_FULLTEXT
# 1309                          ALTO11759921_DDB_FULLTEXT
# 139                            ALTO9193918_DDB_FULLTEXT
#
#                                       preview_reference  \
# 269   https://api.deutsche-digitale-bibliothek.de/bi...
# 1850  https://api.deutsche-digitale-bibliothek.de/bi...
# 995   https://api.deutsche-digitale-bibliothek.de/bi...
# 1373  https://api.deutsche-digitale-bibliothek.de/bi...
# 598   https://api.deutsche-digitale-bibliothek.de/bi...
# 207   https://api.deutsche-digitale-bibliothek.de/bi...
# 1239  https://api.deutsche-digitale-bibliothek.de/bi...
# 617   https://api.deutsche-digitale-bibliothek.de/bi...
# 421   https://api.deutsche-digitale-bibliothek.de/bi...
# 2006  https://api.deutsche-digitale-bibliothek.de/bi...
# 296   https://api.deutsche-digitale-bibliothek.de/bi...
# 38    https://api.deutsche-digitale-bibliothek.de/bi...
# 2314  https://api.deutsche-digitale-bibliothek.de/bi...
# 485   https://api.deutsche-digitale-bibliothek.de/bi...
# 554   https://api.deutsche-digitale-bibliothek.de/bi...
# 101   https://api.deutsche-digitale-bibliothek.de/bi...
# 1867  https://api.deutsche-digitale-bibliothek.de/bi...
# 2288  https://api.deutsche-digitale-bibliothek.de/bi...
# 2242  https://api.deutsche-digitale-bibliothek.de/bi...
# 2191  https://api.deutsche-digitale-bibliothek.de/bi...
# 1372  https://api.deutsche-digitale-bibliothek.de/bi...
# 854   https://api.deutsche-digitale-bibliothek.de/bi...
# 2118  https://api.deutsche-digitale-bibliothek.de/bi...
# 862   https://api.deutsche-digitale-bibliothek.de/bi...
# 1956  https://api.deutsche-digitale-bibliothek.de/bi...
# 351   https://api.deutsche-digitale-bibliothek.de/bi...
# 368   https://api.deutsche-digitale-bibliothek.de/bi...
# 594   https://api.deutsche-digitale-bibliothek.de/bi...
# 700   https://api.deutsche-digitale-bibliothek.de/bi...
# 32    https://api.deutsche-digitale-bibliothek.de/bi...
# 873   https://api.deutsche-digitale-bibliothek.de/bi...
# 234   https://api.deutsche-digitale-bibliothek.de/bi...
# 59    https://api.deutsche-digitale-bibliothek.de/bi...
# 2071  https://api.deutsche-digitale-bibliothek.de/bi...
# 1232  https://api.deutsche-digitale-bibliothek.de/bi...
# 1214  https://api.deutsche-digitale-bibliothek.de/bi...
# 453   https://api.deutsche-digitale-bibliothek.de/bi...
# 2260  https://api.deutsche-digitale-bibliothek.de/bi...
# 242   https://api.deutsche-digitale-bibliothek.de/bi...
# 1141  https://api.deutsche-digitale-bibliothek.de/bi...
# 1525  https://api.deutsche-digitale-bibliothek.de/bi...
# 715   https://api.deutsche-digitale-bibliothek.de/bi...
# 859   https://api.deutsche-digitale-bibliothek.de/bi...
# 1095  https://api.deutsche-digitale-bibliothek.de/bi...
# 405   https://api.deutsche-digitale-bibliothek.de/bi...
# 1909  https://api.deutsche-digitale-bibliothek.de/bi...
# 2239  https://api.deutsche-digitale-bibliothek.de/bi...
# 936   https://api.deutsche-digitale-bibliothek.de/bi...
# 428   https://api.deutsche-digitale-bibliothek.de/bi...
# 993   https://api.deutsche-digitale-bibliothek.de/bi...
# 1973  https://api.deutsche-digitale-bibliothek.de/bi...
# 155   https://api.deutsche-digitale-bibliothek.de/bi...
# 71    https://api.deutsche-digitale-bibliothek.de/bi...
# 31    https://api.deutsche-digitale-bibliothek.de/bi...
# 984   https://api.deutsche-digitale-bibliothek.de/bi...
# 1223  https://api.deutsche-digitale-bibliothek.de/bi...
# 1309  https://api.deutsche-digitale-bibliothek.de/bi...
# 139   https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                       plainpagefulltext  \
# 269   d 8 d c ei n * g .8²ͤ 8 n 2 n Freitag, 9. Sept...
# 1850  verbrecherischer Hasardeur ein Weltreich zugru...
# 995   verbrecherischer Hasardeur ein Weltreich zugru...
# 1373  Seite 6 . Nr . 16241 General = Anzeiger für Vo...
# 598   der deutschspracingen Presse e . V . Folge 294...
# 207   # # und anderwärks dumm . Aber imme Aber die L...
# 1239  Sekte 4 . Nr , 248 Dadlscbe DxcTfc Freitag , d...
# 617   verbrecherischer Hasardeur ein Weltreich zugru...
# 421   verbrecherischer hasardeur ein Weltreich zugru...
# 2006  verdrecherischer Hasardeur ein Weltreich zugru...
# 296   13 . Oktober 1940 Feuenatteinge Dr . Dietrich ...
# 38    8 . BEPTBR . 1938 kusmeister sie europäischen ...
# 2314  # # erischer Anzeiger bordnung Deutschen Hof d...
# 485   Seite 2 Nr . 1817 Bochumer Anzeiger 2 Montag ,...
# 554   # = chang der = Gewissen Die Presselüge unterg...
# 101   Ur. 186. BbenncmenfS'Bcdlngtifigen: Wonncnicnt...
# 1867  April 1942 Harburger Anzeigen und Nachrichten ...
# 2288  Sardpa tlagt die Tagenpresst un Minister von b...
# 2242  M Freitag , den 9 . September Nr . 200 — 98 . ...
# 2191  Tanerratongher Sorrberner Aeltester Anzeiger d...
# 1372  V . Septecaber 1933 General = Anzeiger für Von...
# 854   * Die „ Schwerter Zeitung “ erscheint wöchentl...
# 2118  Pee De . r U . . . n . ne . . 53 flh . für Cas...
# 862   • . * P A N Deragopreto : un dur Pos . 20 NM ....
# 1956  iſche Zeitſchrift „ Ken “ Chicago vom 16 . öhn...
# 351   Mitteleecheeimö selhe Freitag , den 9 . Septem...
# 368   Sonntag 11. Februar 1923 Vonmag 11. Februar 19...
# 594   Seile 2 . Nr . 17 33 . General - Anzeiger für ...
# 700   1933 Nr . 211 te „ AeSruhl kürner Die vernicht...
# 32    Dr. Dietrich erwähnte weiter seine vor den Mit...
# 873   uncn Bear 8 . echeitm mmer be ist und 5 bwehrl...
# 234   . J . des ant - ten furt zu⸗ ung die nem ohn -...
# 59    Rhein - und Ruhrzeitung Nr . 246 Die „ interes...
# 2071  derselben Weissagung „ Licht vom Himmel “ zube...
# 1232  Freitag , den 9 . September 1938 Nr . 247 Neue...
# 1214  Hohmstein-Ernslthaler Tageblatt und^ufeiger 2....
# 453   2 . Blatt Lenndser Eeneßentung 10 . /11 . Sept...
# 2260  ten Aron , anenßehe⸗ N 1 ais her . ache i ekla...
# 242   Freitag, Den 8. September 1938 — Nr. 210 saä e...
# 1141  FOLAE 13 . 12 . 41 General - Anzeiger Seite 2 ...
# 1525  mber nnten Tat - ch die efähr⸗ t nur kann . h ...
# 715   — . • • : ? p * OUTTTTART Anzeigenpreis : Ein ...
# 859   95chr de 157 aler K . 100 45 : er germerte u ....
# 1095  Beilage zum Frankenberger Tageblatt M». HV4 Mo...
# 405   Montag , 13 . April 1942 Kriegsberichter , der...
# 1909  211 Samstag = Konntag , 10 . = 11 . Seotember ...
# 2239  eite A Erſcheinungsweiſe : Täglich 2mal außer ...
# 936   Nummer 293 . „ Durlucher Tugeblutt " — ^ Pst «...
# 428   Licht zu rücken bestrebt ist , um mit derartig...
# 993   Donnerstag , 8 . September 1938 den Sowjets au...
# 1973               —   Reichs⸗ und Staatsanzeiger Nr...
# 155   Äie unheimliche Macht öer zersetzeaöeu Kresse!...
# 71    AL S3 45 54 Au 83 A3 Chautemps in alten Bahnen...
# 31    ein dauerndes Moment der Unruhe und Beunruhi g...
# 984   gekommenen Polizei gelang es vorerst nicht , d...
# 1223  DGR 9 . 9 . 38 General - Anzeiger Seite 5 Vonn...
# 1309  Dieser Sachverhalt ist durch von München an di...
# 139   Donnerstag , 1 . Juli Kölnische Zeitung e Mitt...
#
#                                          processed_text  \
# 269   d  d c ei n  g   n  n freitag  september  nr  ...
# 1850  verbrecherischer hasardeur ein weltreich zugru...
# 995   verbrecherischer hasardeur ein weltreich zugru...
# 1373  seite   nr   general  anzeiger für vonn und um...
# 598   der deutschspracingen presse e  v  folge  er  ...
# 207     und anderwärks dumm  aber imme aber die lese...
# 1239  sekte   nr   dadlscbe dxctfc freitag  de  f   ...
# 617   verbrecherischer hasardeur ein weltreich zugru...
# 421   verbrecherischer hasardeur ein weltreich zugru...
# 2006  verdrecherischer hasardeur ein weltreich zugru...
# 296     oktober  feuenatteinge dr  dietrich über den...
# 38      beptbr   kusmeister sie europäischen leicht ...
# 2314    erischer anzeiger bordnung deutschen hof di ...
# 485   seite  nr   bochumer anzeiger  montag    augus...
# 554     chang der  gewissen die presselüge untergräb...
# 101   ur  bbenncmenfsbcdlngtifigen wonncnicnts  prci...
# 1867  april  harburger anzeigen und nachrichten krei...
# 2288  sardpa tlagt die tagenpresst un minister von b...
# 2242  m freitag  den   september nr      jahrgang er...
# 2191  tanerratongher sorrberner aeltester anzeiger d...
# 1372  v  septecaber  general  anzeiger für vonn und ...
# 854    die  schwerter zeitung  erscheint wöchentlich...
# 2118  pee de  r u    n  ne    flh  für castrop  rauz...
# 862      p a n deragopreto  un dur pos   nm  ehne de...
# 1956  iche zeitchrift  ken  chicago vom   öhnt den d...
# 351   mitteleecheeimö selhe freitag  den   september...
# 368   sonntag  februar  vonmag  februar  lichte sah ...
# 594   seile   nr     general  anzeiger für vonn und ...
# 700    nr   te  aesruhl kürner die vernichtende ankl...
# 32    dr dietrich erwähnte weiter seine vor den mitg...
# 873   uncn bear   echeitm mmer be ist und  bwehrlän ...
# 234    j  des ant  ten furt zu ung die nem ohn  der ...
# 59    rhein  und ruhrzeitung nr   die  interessante ...
# 2071  derselben weissagung  licht vom himmel  zubena...
# 1232  freitag  den   september  nr   neue sag die lü...
# 1214  hohmsteinernslthaler tageblatt undufeiger  bel...
# 453     blatt lenndser eeneßentung     sept   aiunpf...
# 2260  ten aron  anenßehe n  ais her  ache i eklaen a...
# 242   freitag den  september   nr  saä erscheinenden...
# 1141  folae      general  anzeiger seite   geder der...
# 1525  mber nnten tat  ch die efähr t nur kann  h dem...
# 715         p  outtttart anzeigenpreis  ein millimet...
# 859   chr de  aler k     er germerte u  salz  n g  t...
# 1095  beilage zum frankenberger tageblatt m hv monta...
# 405   montag    april  kriegsberichter  der der köln...
# 1909   samstag  konntag       seotember  no rimnäths...
# 2239  eite a ercheinungsweie  täglich mal außer sonn...
# 936   nummer    durlucher tugeblutt    pst  t  ler v...
# 428   licht zu rücken bestrebt ist  um mit derartige...
# 993   donnerstag    september  den sowjets ausgebrac...
# 1973                  reichs und staatsanzeiger nr  ...
# 155   äie unheimliche macht öer zersetzeaöeu kresse ...
# 71    al s   au  a chautemps in alten bahnen ministe...
# 31    ein dauerndes moment der unruhe und beunruhi g...
# 984   gekommenen polizei gelang es vorerst nicht  di...
# 1223  dgr      general  anzeiger seite  vonnieg  hrg...
# 1309  dieser sachverhalt ist durch von münchen an di...
# 139   donnerstag    juli kölnische zeitung e mittags...
#
#                                           context_small  similarity
# 269   Preſſe ſo unmittelbar in das politiſche Geſche...    0.764363
# 1850   Weltpresse einen entscheidenden Stoß versetzt...    0.735866
# 995   Weltpresse einen entscheidenden Stoß versetzt ...    0.731029
# 1373  hm die Schilderung in Form von Nachrichten gem...    0.710845
# 598   ische Mordwaffen / 72 v . H . aller englischen...    0.706496
# 207   m die Schilderung in Form von Nachrichten gema...    0.706107
# 1239  mern in Zivil , von diesen Kriegsberichterstat...    0.699713
# 617   n Weltpresse einen entscheidenden Stoß versetz...    0.698975
# 421   n Weltpresse einen entscheidenden Stoß versetz...    0.698975
# 2006  n Weltpresse einen entscheidenden Stoß versetz...    0.698975
# 296   tt , die sich mit aktuellen journalisti . iche...    0.698780
# 38    hrte sen , welche die n Jahren ein r Presse . ...    0.694674
# 2314  rlie ud anständigen Fakloren der inlernational...    0.683290
# 485   war , wird jetzt Zug um Zug getan . ( Neuer Be...    0.677880
# 554    . Das Wunder der modernen Nachrichtenorganisa...    0.675211
# 101   ne Haut angehen, selbständig zu denken beginnt...    0.673503
# 1867  d eine Verantwortung trägt, die aber in ihrer ...    0.663650
# 2288  tand der Truppen in Aethiovien ins Lächerliche...    0.661950
# 2242  und unanfechtbaren Tat sachenmaterials einen i...    0.658557
# 2191  und unanfechtbaren Tat sachenmaterials einen i...    0.658557
# 1372   Kloß . Der Stellventreter des Führero eröffne...    0.656235
# 854   eichen und unanfechtbaren Tatsachenmaterials e...    0.653055
# 2118  eichen und unanfechtbaren Tatsachenmaterials e...    0.653055
# 862   und unanfechtbaren Tat sachenmaterials einen i...    0.651546
# 1956  häftigte , von ſeinen an eblichen militä⸗ riſc...    0.645835
# 351   und unanfechtbaren Tat lachenmaterials einen i...    0.644353
# 368   triert. In de» verschiedensten Reserve in dem ...    0.643677
# 594   mmen , für die sich die Schriftleiter aller ju...    0.642936
# 700   zer in aller Welt Auf dem Parteikongreß hielt ...    0.642505
# 32    r Demokratie aus die deutschen Anklagen und Vo...    0.642052
# 873   utlicht werden kann . Aus der Legion zynischer...    0.640493
# 234   ereſſanten Anſtrich zu geben ſuchen , daß ſie ...    0.636374
# 59    rvermittlungswerkzeug der Welt . Ich glaube , ...    0.635015
# 2071  elegenheit . Von diesen großartigen Erfolgen ,...    0.634031
# 1232  Welt zu Nürnberg , 8 . Sept . Auf dem Parteiko...    0.633458
# 1214  t die Entdeckung gemacht, daß von sieben der n...    0.633213
# 453    . Nürnberg , 8 . Sept . Auf dem Parteikongreß...    0.633170
# 2260   Vereinigten Staaten über das Preſſeweſen , Fr...    0.633143
# 242   Freitag, Den 8. September 1938 — Nr. 210 saä e...    0.631347
# 1141  r , das seit der Französischen Revolution der ...    0.627778
# 1525  ereinigten Staaten Eingang gefunden hat . Er m...    0.627529
# 715   e zu bedienen , da die Wahrheit im autoritä re...    0.627028
# 859   e zu bedienen , da die Wahrheit im autoritä re...    0.627028
# 1095  aft fei zum Schrittmacher des menschlichen For...    0.623748
# 405   te bereits eine über nationale Plattform dar ,...    0.622708
# 1909  er in aller Welt Auf dem Parteikongreß hielt R...    0.621868
# 2239   gegen England in der italieniſchen Preſſe etw...    0.619361
# 936   t beweglichen Lettern erfand , seit König die ...    0.615971
# 428   Licht zu rücken bestrebt ist , um mit derartig...    0.614876
# 993   reß und erteilt zunächst Reichsleiter Dr . Fra...    0.614107
# 1973  en, wenn Sie die Preſſe dazu benutzen wollten,...    0.612666
# 155    zersetzeaöeu Kresse! Mrnberg . Auf dem Partei...    0.609786
# 71     Kammeraussprache eine sehr geteilte Auf Rh de...    0.606383
# 31    ein dauerndes Moment der Unruhe und Beunruhi g...    0.605805
# 984   Presse dergleichen Nahrung verlange ; vielmehr...    0.605431
# 1223  B Nürnberg . 8 . Sepl . Auf dem Parteikongreß ...    0.602624
# 1309  Dieser Sachverhalt ist durch von München an di...    0.602604
# 139   men sollte , sich als solcher auf demselben zu...    0.601903
